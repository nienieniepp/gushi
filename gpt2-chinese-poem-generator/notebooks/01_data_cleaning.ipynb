# %% [markdown]
# # 01 Data Cleaning\n\nThis notebook demonstrates preprocessing for chinese-poetry and exports `data/processed/poems.txt`.

# %%
# !python ../src/prepare_data.py --input_dir ../data/raw --output_file ../data/processed/poems.txt
