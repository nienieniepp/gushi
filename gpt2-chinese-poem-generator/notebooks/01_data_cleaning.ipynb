# %% [markdown]
# # 01 数据清洗（chinese-poetry）
#
# 本 Notebook 对目录下**所有** `poet.tang.*.json` 文件进行遍历清洗，并导出每行一首诗。
#
# 筛选规则：
# - 恰好 4 句
# - 每句恰好 5 或 7 个中文字符
# - 句子之间用 `。` 拼接
# - 最终去重

# %%
# 运行数据清洗脚本（注意：会递归处理 input_dir 下全部 poet.tang.*.json 文件）
# !python ../data/process_data.py --input_dir ../data/raw --output_file ../data/processed/tang_poems_4x5or7.txt

# %%
# 查看前 5 行结果
from pathlib import Path
out = Path('../data/processed/tang_poems_4x5or7.txt')
if out.exists():
    with out.open('r', encoding='utf-8') as f:
        for i, line in zip(range(5), f):
            print(line.strip())
else:
    print('输出文件不存在，请先运行上一个单元。')
